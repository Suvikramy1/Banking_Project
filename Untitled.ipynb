# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
df=pd.read_csv('/home/suvikram/Downloads/datasets/Banking subscription/bank-additional-full.csv', sep=';')
df.drop_duplicates()
df['y_cat']=df['y'].map({'yes':1,'no':0})
y_cat=df['y']
df['contact']=df['contact'].map({'telephone':1,'cellular':0})
df['default']=df['default'].map({'yes':-1,'no':1,'unknown':0})
df['housing']=df['housing'].map({'yes':-1,'no':1,'unknown':0})
df['loan']=df['loan'].map({'yes':-1,'no':1,'unknown':0})
en_month={j:i for i,j in enumerate(df['month'].unique())}
df['month']=df['month'].map(en_month)
en_month={j:i for i,j in enumerate(df['day_of_week'].unique())}
df['day_of_week']=df['day_of_week'].map(en_month)
df['poutcome']=df['poutcome'].map({'success':1,'failure':-1,'nonexistent':0})
df[df['pdays']!=999]['pdays'].count()/df['pdays'].count()
df['education']=df['education'].map({'basic.4y':2, 'high.school':3, 'basic.6y':4, 'basic.9y':5,
       'professional.course':6, 'unknown':1, 'university.degree':7,
       'illiterate':0})
df
# Out:
#        age          job  marital  education  default  housing  loan  contact  \
# 0       56    housemaid  married          2        1        1     1        1
# 1       57     services  married          3        0        1     1        1
# 2       37     services  married          3        1       -1     1        1
# 3       40       admin.  married          4        1        1     1        1
# 4       56     services  married          3        1        1    -1        1
# ...    ...          ...      ...        ...      ...      ...   ...      ...
# 41183   73      retired  married          6        1       -1     1        0
# 41184   46  blue-collar  married          6        1        1     1        0
# 41185   56      retired  married          7        1       -1     1        0
# 41186   44   technician  married          6        1        1     1        0
# 41187   74      retired  married          6        1       -1     1        0
#
# ...

# %%
dum_df = pd.get_dummies(df['marital'],  prefix="Type_is",drop_first=True )


df=pd.concat([df,dum_df],axis=1)
df.job.value_counts()
#fig = plt.figure()
ordered_labels = df.groupby('job')['y_cat'].mean().sort_values().index
ordinal_label = {k:i for i, k in enumerate(ordered_labels, 0)}
df['job']=df['job'].map(ordinal_label)

df
ordered_labels
# Out:
# Index(['blue-collar', 'services', 'entrepreneur', 'housemaid', 'self-employed',
#        'technician', 'unknown', 'management', 'admin.', 'unemployed',
#        'retired', 'student'],
#       dtype='object', name='job')

# %%
y = pd.get_dummies(y_cat,  prefix="Type_is")

# %%
df.columns
df_cat=df.select_dtypes(include=['object'])
df_num=df.select_dtypes(exclude=['object'])
df[['job','emp.var.rate','nr.employed']]
df['nr.employed' ].value_counts()
df['emp.var.rate'].value_counts()
df[df['nr.employed'].isin([5099.1,5008.7])]

#df['cons.conf.idx'].value_counts()
#df['euribor3m' ].value_counts()
df['cons.price.idx' ].value_counts()
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df_scaled=scaler.fit_transform(df)
np.size(df_scaled)
df_X =pd.DataFrame(df_scaled,columns=df.columns)

# %%
from scipy.stats import norm
from scipy import stats
df_num.describe()
df_num['previous'].value_counts()
def fn_Validate_Norm(df_num):
    for i in ['age']:
        ks_test = stats.kstest(df_num[i],'norm')
        if(ks_test[1]>0.05):
            lower_boundary=df_num[i].mean() - 3*df_num[i].std()
            upper_boundary=df_num[i].mean() + 3*df_num[i].std()
        else:
            IQR = df_num[i].quantile(0.75) - df_num[i].quantile(0.25)
            lower_boundary= df_num[i].quantile(0.25) -3*IQR
            upper_boundary= df_num[i].quantile(0.75) +3*IQR
        df_num.loc[df_num[i]<lower_boundary,[i]]=lower_boundary
        df_num.loc[df_num[i]>upper_boundary,[i]]=upper_boundary

fn_Validate_Norm(df_num)

# %%
df_num.loc[df_num['pdays']==999,'pdays']=-1
df_num
# Out:
#         age  job  education  default  housing  loan  contact  month  \
# 0      56.0    3          2        1        1     1        1      0
# 1      57.0    1          3        0        1     1        1      0
# 2      37.0    1          3        1       -1     1        1      0
# 3      40.0    8          4        1        1     1        1      0
# 4      56.0    1          3        1        1    -1        1      0
# ...     ...  ...        ...      ...      ...   ...      ...    ...
# 41183  73.0   10          6        1       -1     1        0      5
# 41184  46.0    0          6        1        1     1        0      5
# 41185  56.0   10          7        1       -1     1        0      5
# 41186  44.0    5          6        1        1     1        0      5
# 41187  74.0   10          6        1       -1     1        0      5
#
#        day_of_week  campaign  ...  poutcome  emp.var.rate  cons.price.idx  \
# 0                0         1  ...         0           1.1          93.994
# ...

# %%
stats.kstest(df_num['age'],'norm')
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %%
df_num.isnull().sum()  #Indicates no nulls in the data
# Out:
# age                0
# job                0
# education          0
# default            0
# housing            0
# loan               0
# contact            0
# month              0
# day_of_week        0
# campaign           0
# pdays              0
# previous           0
# poutcome           0
# emp.var.rate       0
# cons.price.idx     0
# cons.conf.idx      0
# euribor3m          0
# nr.employed        0
# Type_is_married    0
# Type_is_single     0
# Type_is_unknown    0
# dtype: int64

# %%
fig = df_num.boxplot(figsize=[20,20],fontsize=40)
plt.ylim(0,100)
fig = df_num.boxplot(column='previous')
df_num
# Out:
#         age  job  education  default  housing  loan  contact  month  \
# 0      56.0    3          2        1        1     1        1      0
# 1      57.0    1          3        0        1     1        1      0
# 2      37.0    1          3        1       -1     1        1      0
# 3      40.0    8          4        1        1     1        1      0
# 4      56.0    1          3        1        1    -1        1      0
# ...     ...  ...        ...      ...      ...   ...      ...    ...
# 41183  73.0   10          6        1       -1     1        0      5
# 41184  46.0    0          6        1        1     1        0      5
# 41185  56.0   10          7        1       -1     1        0      5
# 41186  44.0    5          6        1        1     1        0      5
# 41187  74.0   10          6        1       -1     1        0      5
#
#        day_of_week  campaign  ...  previous  poutcome  emp.var.rate  \
# 0                0         1  ...         0         0           1.1
# ...

# %%
import tensorflow as tf

# %%
learning_rate = 0.01
training_epochs = 25
batch_size = 100
display_step = 1
#df.drop(['marital','y_cat','duration'],axis=1,inplace=True)
df.drop(['y_cat'],axis=1,inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df_X, y, test_size=0.3, random_state=0)

X_train.shape, X_test.shape

#df_X = tf.data.Dataset.from_tensors(X_train.values)
# Out:
# ((28831, 22), (12357, 22))

# %%
X = tf.placeholder(tf.float32, [None,X_train.shape[1] ]) 
Y=tf.placeholder(tf.float32, [None, 2])
y_train.shape,y_test.shape
# Out:
# ((28831, 2), (12357, 2))

# %%
# Create model
# Set model weights
W = tf.Variable(tf.zeros([X_train.shape[1],2]))
b = tf.Variable(tf.zeros([2]))
df_train.shape
# Out:
# TensorShape([Dimension(None), Dimension(21)])

# %%
Y_hat = tf.nn.sigmoid(tf.add(tf.matmul(X, W), b))
cost = tf.nn.sigmoid_cross_entropy_with_logits(logits = Y_hat, labels = Y)  
# Softmaxtf.nn.sigmoid_cross_entropy_with_logits

# %%
#cost = tf.nn.sigmoid_cross_entropy_with_logits(logits = Y_hat, labels = Y) 
# Minimize error using cross entropy
# Cross entropy
#cost = -tf.reduce_sum(Y*tf.log(activation)) 
# Gradient Descent
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)

# %%
# Initializing the variables
init = tf.initialize_all_variables()

# %%
#launch the session
with tf.Session() as ss:
    ss.run(init)
    avg_cost = 0.
    # Training cycle
    for epoch in range(training_epochs):
        avg_cost =0
        #total_batch = int(X_train.shape[0]/batch_size)
        # Loop over all batches
        batch_xs, batch_ys = X_train, y_train
        # Fit training using batch data
        ss.run(optimizer, feed_dict={X: batch_xs, Y: batch_ys})
        # Compute average loss
        avg_cost = avg_cost+ss.run(cost, feed_dict={X: batch_xs, Y: batch_ys})
        # Display logs per epoch step
        if epoch % display_step == 0:
            print("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(sum(sum(avg_cost))))

    print("Optimization Finished!")
    correct_prediction = tf.equal(tf.argmax(Y_hat, 1), 
                              tf.argmax(Y, 1)) 
    accuracy = tf.reduce_mean(tf.cast(correct_prediction,  
                                             tf.float32)) 
    print("\nAccuracy:", accuracy.eval({X:X_train,Y:y_train}), "%")
    print("\nAccuracy:", accuracy.eval({X:X_test,Y:y_test}), "%")
# Out:
# Epoch: 0001 cost= 31679.404296875
# Epoch: 0002 cost= 30796.022460938
# Epoch: 0003 cost= 30118.358398438
# Epoch: 0004 cost= 29832.284179688
# Epoch: 0005 cost= 29778.095703125
# Epoch: 0006 cost= 29713.213867188
# Epoch: 0007 cost= 29617.720703125
# Epoch: 0008 cost= 29521.324218750
# Epoch: 0009 cost= 29437.212890625
# Epoch: 0010 cost= 29419.440429688
# Epoch: 0011 cost= 29413.576171875
# Epoch: 0012 cost= 29410.878906250
# Epoch: 0013 cost= 29409.287109375
# Epoch: 0014 cost= 29408.026367188
# Epoch: 0015 cost= 29406.898437500
# Epoch: 0016 cost= 29405.849609375
# Epoch: 0017 cost= 29404.897460938
# Epoch: 0018 cost= 29404.083984375
# Epoch: 0019 cost= 29403.376953125
# Epoch: 0020 cost= 29402.746093750
# Epoch: 0021 cost= 29402.154296875
# Epoch: 0022 cost= 29401.585937500
# Epoch: 0023 cost= 29401.045898438
# Epoch: 0024 cost= 29400.573242188
# Epoch: 0025 cost= 29400.191406250
# Optimization Finished!
#
# Accuracy: 0.9868891 %
#
# Accuracy: 0.9856761 %
